# %% [markdown]
# Собянин Максим, РИ-411003

# %%
# %%capture
# %%bash

apt install -y libboost-all-dev
pip install -U pip
pip install "pybind11[global]"

# %%
pip install aijack==0.0.1b1
# Out:
# Requirement already satisfied: aijack==0.0.1b1 in /usr/local/lib/python3.10/dist-packages (0.0.1b1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (1.6.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (0.20.1+cu121)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (4.10.0.84)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (2.13.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (3.8.0)
# Requirement already satisfied: mpi4py in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (4.0.1)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from aijack==0.0.1b1) (0.14.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->aijack==0.0.1b1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->aijack==0.0.1b1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->aijack==0.0.1b1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->aijack==0.0.1b1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->aijack==0.0.1b1) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->aijack==0.0.1b1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->aijack==0.0.1b1) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->aijack==0.0.1b1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->aijack==0.0.1b1) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->aijack==0.0.1b1) (2024.2)
# Requirement already satisfied: pybind11-global==2.13.6 in /usr/local/lib/python3.10/dist-packages (from pybind11[global]->aijack==0.0.1b1) (2.13.6)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->aijack==0.0.1b1) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->aijack==0.0.1b1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->aijack==0.0.1b1) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels->aijack==0.0.1b1) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->aijack==0.0.1b1) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->aijack==0.0.1b1) (3.0.2)

# %%
import os
import copy
import random

import kagglehub

import numpy as np
import pandas as pd

from aijack.attack import Poison_attack_sklearn

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

# %%
random.seed(42)

# %% [markdown]
# Загрузим данные

# %%
path = kagglehub.dataset_download("dhoogla/distrinetcicids2017")
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.5), please consider upgrading to the latest version (0.3.6).
# Path to dataset files: /root/.cache/kagglehub/datasets/dhoogla/distrinetcicids2017/versions/5

# %%
dfps = []

for dirname, _, filenames in os.walk('/root/.cache/kagglehub/datasets/dhoogla/distrinetcicids2017/versions/5'):
    for filename in filenames:
        if filename.endswith('.parquet'):
            dfp = os.path.join(dirname, filename)
            dfps.append(dfp)
            print(dfp)
# Out:
# /root/.cache/kagglehub/datasets/dhoogla/distrinetcicids2017/versions/5/DoS-Wednesday.parquet
# /root/.cache/kagglehub/datasets/dhoogla/distrinetcicids2017/versions/5/Benign-Monday.parquet
# /root/.cache/kagglehub/datasets/dhoogla/distrinetcicids2017/versions/5/Bruteforce-Tuesday.parquet
# /root/.cache/kagglehub/datasets/dhoogla/distrinetcicids2017/versions/5/Portscan-DDos-Botnet-Friday.parquet
# /root/.cache/kagglehub/datasets/dhoogla/distrinetcicids2017/versions/5/Infiltration-Webattacks-Thursday.parquet

# %%
dfps = [dfp for dfp in dfps if not 'Benign' in dfp]

# %%
df = pd.concat([pd.read_parquet(dfp) for dfp in dfps], ignore_index=True)
df.shape
# Out:
# (1436640, 83)

# %% [markdown]
# Датасет предназначен для задачи многоклассовой классификации, но мы упростим ее и сведем к бинарной - бинарная классификация на нормальный и аномальный трафик.

# %%
target = 'Label'

df[target] = df[target].replace('Attempted-relabel-as-Benign', 'Benign')
df.Label.value_counts() # benign - хороший трафик, остальное - нет
# Out:
# Label
# Benign                        1154753
# DoS Hulk                       158449
# DDoS                            95144
# DoS GoldenEye                    7567
# Infiltration - Portscan          5485
# DoS Slowloris                    3998
# FTP-Patator                      3972
# SSH-Patator                      2961
# DoS Slowhttptest                 1741
# Portscan                         1683
# Botnet                            736
# Web Attack - Brute Force           73
# Infiltration                       36
# Web Attack - XSS                   18
# Web Attack - SQL Injection         13
# Heartbleed                         11
# Name: count, dtype: int64

# %%
df.loc[df['Label'] != 'Benign', 'Label'] = 1
df.loc[df['Label'] == 'Benign', 'Label'] = 0

df['Label'] = df['Label'].astype(dtype=np.int32)

df['Label'].value_counts(normalize=True)
# Out:
# Label
# 0    0.803787
# 1    0.196213
# Name: proportion, dtype: float64

# %% [markdown]
# ### Train-test split

# %% [markdown]
# Для ускорения обучения моделей используем лишь часть данных

# %%
X, X_test, y, y_test = train_test_split(
    df.drop(columns=['Label']),
    df['Label'],
    test_size=0.01,
    random_state=42,
)
X, X_train, y, y_train = train_test_split(
    X,
    y,
    test_size=0.05,
    random_state=42,
)
X_train.shape, X_test.shape
# Out:
# ((71114, 82), (14367, 82))

# %% [markdown]
# ### Constant Baseline

# %% [markdown]
# Константный бейзлайн в виде самого частотного класса предсказуемо не показывает хорошего качества

# %%
roc_auc_score(y_true=y_test, y_score=[0.0]*len(y_test))
# Out:
# 0.5

# %% [markdown]
# ### SVM

# %% [markdown]
# Метод опорных векторов, напротив, демонстрирует хорошую производительность...

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
model = SVC(kernel="linear", C=1, random_state=42)

model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
roc_auc_score(y_true=y_test, y_score=y_pred)
# Out:
# 0.987068040285753

# %% [markdown]
# #### SVC Interpretation

# %% [markdown]
# Давайте выясним, почему эта модель так хорошо работает.
#
# Интерпретируйте работу обученной SVC-модели в ячейке ниже, для этого создайте bar-plot с визуализацией весов модели.
#
# **Hint**: метод опорных векторов является линейной моделью, поэтому его интерпретация мало чем отличается от интерпретации линейной регрессии

# %%
import matplotlib.pyplot as plt

# Получаем веса модели
weights = model.coef_[0]
# Получаем индексы топ-20 весов
top_20_indices = np.argsort(np.abs(weights))[-20:]

# Строим bar-plot
plt.figure(figsize=(12, 8))
plt.barh(range(20), weights[top_20_indices], tick_label=X_train.columns[top_20_indices])
plt.xlabel('Вес признака')
plt.ylabel('Признак')
plt.title('Топ-20 признаков SVC модели')
plt.show()

# %% [markdown]
# #### SVC Attack - Data poison

# %% [markdown]
# Выберем объект, который будем "отравлять"

# %%
# initial point
initial_idx = 11
xc = copy.deepcopy(X_train_scaled[initial_idx, :])
yc = y_train.iloc[initial_idx]

# %% [markdown]
# Создадим небольшие train/test подвыборки для ускорения процесса обучения

# %%
train_idx = random.sample(list(range(1, X_train_scaled.shape[0])), 500)
X_train_ = copy.copy(X_train_scaled[train_idx, :])
y_train_ = copy.copy(y_train.iloc[train_idx]).values

# %%
test_idx = random.sample(list(range(1, X_test_scaled.shape[0])), 500)
X_test_ = copy.copy(X_test_scaled[test_idx, :])
y_test_ = copy.copy(y_test.iloc[test_idx]).values

# %% [markdown]
# aijack ожидает, что метки классов будут иметь вид 1/-1

# %%
y_train_ = np.where(y_train_ == 1, 1, -1)
y_test_ = np.where(y_test_ == 1, 1, -1)

# %% [markdown]
# Создайте attacker и "отравленный" объект

# %%
attacker =

xc_attacked, log =
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-9625af8c5697> in <cell line: 8>()
#       6 )
#       7
# ----> 8 xc_attacked, log = attacker.attack(
#       9     xc=xc,
#      10     yc=yc,
#
# /usr/local/lib/python3.10/dist-packages/aijack/attack/poison/poison_attack.py in attack(self, xc, yc, X_valid, y_valid, num_iterations)
#     150
#     151             # the desired gradient used for optimizing our attack:
# --> 152             delta_L = np.sum(((Mk.dot(delta_Qsc) + delta_Qkc) * alpha), axis=0)
#     153
#     154             # u is a norm-1 vector representing the attack direction,
#
# ValueError: operands could not be broadcast together with shapes (500,82) (1,3)

# %% [markdown]
# Посмотрим, насколько будет падать качество классификации до и после добавления "отравленного" объекта в модель

# %%
clf = SVC(kernel="linear", C=1, random_state=42)
clf.fit(X_train_, y_train_)
print("before attack: ", roc_auc_score(y_true=y_test_, y_score=clf.predict(X_test_)))

# add poinsoned data
clf = SVC(kernel="linear", C=1, random_state=42)
clf.fit(
    np.concatenate([X_train_, xc_attacked.reshape(1, -1)]),
    np.concatenate([y_train_, [-1]]),
)

assert roc_auc_score(y_true=y_test_, y_score=clf.predict(X_test_)) < 0.9769
print("after attack: ", roc_auc_score(y_true=y_test_, y_score=clf.predict(X_test_)))
# Out:
# before attack:  0.980527360988526
# after attack:  0.9768865842894968

# %% [markdown]
# ### Random Forest

# %% [markdown]
# Обучите модель случайного леса для рещения задачи

# %%
# %%time

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
roc_auc_score(y_true=y_test, y_score=rf.predict(X_test))
# Out:
# CPU times: user 32.5 s, sys: 56.8 ms, total: 32.6 s
# Wall time: 39.8 s
# 0.997707335446204

# %% [markdown]
# #### Random Forest Interpretation

# %% [markdown]
# Интерпретируйте предсказания случайного леса
# - с использованием `permutation_importance`
# - с использованием `shap`
# - с использованием `lime` для двух любых объектов - с метками 0 и 1

# %% [markdown]
# * permutation_importance

# %%
from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(rf, X_test, y_test, random_state=42)
sorted_idx = perm_importance.importances_mean.argsort()

# Бар-диаграмма важности признаков
plt.figure(figsize=(12, 8))
plt.barh(X_train.columns[sorted_idx][-20:], perm_importance.importances_mean[sorted_idx][-20:])
plt.xlabel("Среднее значение изменения метрики")
plt.ylabel("Признак")
plt.title("Permutation Importance для Random Forest")
plt.show()

# %% [markdown]
# * shap

# %%
import shap

# Расчет SHAP значений
explainer = shap.Explainer(rf)
shap_values = explainer(X_test)

# SHAP значения для класса 0
shap_values_class0 = shap_values[..., 0]

# Построение бар-графика для класса 0
shap.plots.bar(shap_values_class0, max_display=20)

# %% [markdown]
# * lime

# %%
# !pip install lime
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from lime) (3.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lime) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from lime) (1.6.0)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.10/dist-packages (from lime) (0.25.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (11.0.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2.36.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (2024.12.12)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->lime) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=eb984688f908b613df601b9d40b6c6cf646606cd1967279278a0c5b997a184cd
#   Stored in directory: /root/.cache/pip/wheels/fd/a2/af/9ac0a1a85a27f314a06b39e1f492bee1547d52549a4606ed89
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
from lime.lime_tabular import LimeTabularExplainer
import matplotlib.pyplot as plt

# Создаем объект LIME объяснителя
explainer = LimeTabularExplainer(
    X_train.values,
    training_labels=y_train.values,
    feature_names=X_train.columns,
    mode="classification"
)

num_features = 20

# Интерпретация для объекта с меткой 0
exp_0 = explainer.explain_instance(
    X_test.iloc[0].values,
    rf.predict_proba,
    num_features=num_features
)
fig_0 = exp_0.as_pyplot_figure()
plt.title("Local explanation for class 0 (top 20 features)")
plt.show()

# Интерпретация для объекта с меткой 1
exp_1 = explainer.explain_instance(
    X_test.iloc[1].values,
    rf.predict_proba,
    num_features=num_features
)
fig_1 = exp_1.as_pyplot_figure()
plt.title("Local explanation for class 1 (top 20 features)")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
